# %%
import pandas as pd

# %%
name_df = pd.read_csv('./gardenName.csv')
df = pd.read_csv('./gardenDtl_2.csv')

# %%
merged_df = pd.merge(name_df, df, how='outer', on='cntntsNo')

# %%
merged_df
# Out:
#      cntntsNo          cntntsSj                                   Unnamed: 0  \
# 0       12938             가울테리아                    식용, 지피, 약용, 향기,관엽, 관화, 관실
# 1       12954               개운죽  대나무를 닮아서 이름까지 얻게 되었지만 사실은 대나무가 아닌 드라세나속의 관엽
# 2       12955       골드크레스트 '윌마'        부드러운 연두빛의 침엽수를 연상하게 하는 실내식물로 허브 향을 지님
# 3       12957              공작야자                            방풍 / 차폐 / 가장자리 경계
# 4       12962            관엽베고니아                                          NaN
# ..        ...               ...                                          ...
# 212     12932               황금죽                                          NaN
# 213     12956             후피향나무                                          NaN
# 214     12920           흰꽃나도사프란                                          NaN
# 215     12919  흰줄무늬달개비(트라데스칸티아)                    덩굴성 관엽/ 빛이 잘 드는 곳, 행잉 바스켓
# 216     12901            히포에스테스                                          NaN
#
# ...

# %%
merged_df.to_csv("./merged_df.csv",index=False)
